# %% [markdown]
# <a href="https://colab.research.google.com/github/MyJmKika/Colab-notebooks/blob/main/notebooks/SoulX_FlashHead_by_AIQUEST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style='text-align: center; padding: 30px; background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); border-radius: 15px; margin: 10px 0; box-shadow: 0 10px 30px rgba(0,0,0,0.2);'>
#   <h1 style='color: white; margin: 0 0 8px 0; font-size: 2.5em;'>🎬 SoulX FlashHead - AI Talking Head Generator</h1>
#   <h3 style='color: #f0f0f0; margin: 0 0 5px 0; font-weight: 400;'>Audio-Driven Portrait Animation - Created by <strong>AIQUEST</strong></h3>
#   <p style='color: #ddd; margin: 0 0 20px 0;'>Free on Google Colab T4 GPU | Open Source</p>
# </div>
#
# ---
#
# <div align="center">
#
#   <img src="https://img.shields.io/badge/AIQUESTAcademy-blueviolet?style=for-the-badge&logo=youtube&logoColor=white" />
#   <img src="https://img.shields.io/badge/Colab-Free%20Tier-orange?style=for-the-badge&logo=googlecolab&logoColor=white" />
#
#  <br>
#
#   <a href="https://www.youtube.com/@aiquestacademy?sub_confirmation=1">
#     <img src="https://img.shields.io/badge/▶%20Subscribe%20on%20YouTube-FF0000?style=for-the-badge&logo=youtube&logoColor=white" />
#   </a>
#   &nbsp;
#   <a href="https://x.com/aiquestacademy">
#     <img src="https://img.shields.io/badge/Follow%20on%20𝕏-0000?style=for-the-badge&logo=x&logoColor=white" />
#   </a>
#
# </div>
#
# ---
#
#
# ### About This Notebook
#
# This notebook runs **SoulX FlashHead both Lite & Pro** — an audio-driven talking head generator with a full Gradio interface:
#
# | Feature | Description |
# |----|----|
# | **Lite & Pro Models** | Choose between fast Lite or high-quality Pro mode |
# | **Audio-Driven Animation** | Animate portraits with any audio/speech input |
# | **Wav2Vec2 Integration** | Facebook's wav2vec2 for audio feature extraction |
# | **Gradio Web UI** | Easy-to-use interface with shareable public link |
# | **Colab Optimized** | Runs on free T4 GPU with no restart needed |
#
# ### Before You Start
# > Go to **Runtime -> Change runtime type -> T4 GPU**

# %%
# @title Step 1: 🔍 GPU Check & PyTorch Verification
# !nvidia-smi --query-gpu=name,memory.total,driver_version --format=csv
print()

import torch
print(f"PyTorch {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")

if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB")
    try:
        x = torch.zeros(1, device="cuda")
        del x
        print("\n✅ PyTorch CUDA is working!")
    except Exception as e:
        print(f"\n⚠️ CUDA test failed: {e}")
else:
    print("\n❌ No GPU detected! Go to Runtime → Change runtime type → T4 GPU")
# Out:
# name, memory.total [MiB], driver_version
# Tesla T4, 15360 MiB, 580.82.07
#
# PyTorch 2.10.0+cu128
# CUDA available: True
# CUDA version: 12.8
# GPU: Tesla T4
# VRAM: 14.6 GB
#
# ✅ PyTorch CUDA is working!

# %%
# @title Step 2: 📥 Clone Repo & Install System Dependencies
import os

print("📦 Installing system dependencies...")
# !apt-get install -y ffmpeg -q

print("\n📥 Cloning SoulX-FlashHead repository...")
if os.path.exists("/content/SoulX-FlashHead"):
    print("📂 Repository exists, pulling latest...")
    # %cd /content/SoulX-FlashHead
    # !git pull
else:
    # !git clone https://github.com/Soul-AILab/SoulX-FlashHead.git
    # %cd /content/SoulX-FlashHead

# !ls
print("\n✅ Repository cloned & system deps installed!")
# Out:
# 📦 Installing system dependencies...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.
#
# 📥 Cloning SoulX-FlashHead repository...
# Cloning into 'SoulX-FlashHead'...
# remote: Enumerating objects: 150, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 150 (delta 31), reused 25 (delta 17), pack-reused 90 (from 1)
# Receiving objects: 100% (150/150), 6.33 MiB | 14.75 MiB/s, done.
# Resolving deltas: 100% (42/42), done.
# /content/SoulX-FlashHead
# assets			 inference_script_multi_gpu_pro.sh
# examples		 inference_script_single_gpu_lite.sh
# flash_head		 inference_script_single_gpu_pro.sh
# generate_video.py	 LICENSE
# gradio_app.py		 README.md
# gradio_app_streaming.py  requirements.txt
#
# ✅ Repository cloned & system deps installed!

# %%
# @title Step 3: ⚙️ Install Python Dependencies
# Strategy: Do NOT replace Colab's default torch. Install deps on top of it.

print("📦 Installing xformers...")
# !pip install -q xformers

print("\n📦 Installing core dependencies (2-3 minutes)...")
# !pip install -q \
    "opencv-python-headless>=4.12.0.88" \
    "diffusers>=0.34.0" \
    "transformers==4.57.3" \
    "tokenizers>=0.20.3" \
    "accelerate>=1.8.1" \
    tqdm imageio easydict ftfy \
    "imageio-ffmpeg" \
    scikit-image \
    loguru \
    "gradio>=5.0.0" \
    pyloudnorm \
    decord \
    librosa \
    "mediapipe>=0.10.13" \
    flask \
    huggingface_hub

print("\n📦 Installing xfuser...")
# !pip install -q "xfuser>=0.4.3" || pip install -q "xfuser>=0.4.3" --no-deps
# !pip install -q yunchang distvae sentencepiece beautifulsoup4 einops 2>/dev/null || true

print("\n✅ All dependencies installed!")
print("─" * 50)

import torch
print(f"🔧 torch: {torch.__version__}")
print(f"🔧 CUDA available: {torch.cuda.is_available()}")
try:
    import xformers; print(f"🔧 xformers: {xformers.__version__}")
except: print("⚠️ xformers: NOT FOUND")
try:
    import xfuser; print(f"🔧 xfuser: OK ({xfuser.__version__})")
except Exception as e: print(f"⚠️ xfuser: FAILED — {e}")
try:
    import diffusers; print(f"🔧 diffusers: {diffusers.__version__}")
except: print("⚠️ diffusers: NOT FOUND")
# Out:
# 📦 Installing xformers...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 48.4 MB/s eta 0:00:00
#
# 📦 Installing core dependencies (2-3 minutes)...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 105.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 114.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 124.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 52.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 16.7 MB/s eta 0:00:00
#
# 📦 Installing xfuser...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.4/241.4 kB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 6.4 MB/s eta 0:00:00
#
# ✅ All dependencies installed!
# ──────────────────────────────────────────────────
# 🔧 torch: 2.10.0+cu128
# 🔧 CUDA available: True
# 🔧 xformers: 0.0.35
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# ⚠️ xfuser: FAILED — module 'xfuser' has no attribute '__version__'
# 🔧 diffusers: 0.37.1

# %%
# @title Step 4: 📥 Download Models
import os

CKPT_DIR    = "/content/models/SoulX-FlashHead-1_3B"
WAV2VEC_DIR = "/content/models/wav2vec2-base-960h"

os.makedirs(CKPT_DIR, exist_ok=True)
os.makedirs(WAV2VEC_DIR, exist_ok=True)

print("📥 Downloading SoulX-FlashHead-1_3B...")
# !huggingface-cli download Soul-AILab/SoulX-FlashHead-1_3B \
    --local-dir {CKPT_DIR} 2>&1 | grep -E "Fetching|Downloading|100%|%\|"

print("\n📥 Downloading wav2vec2-base-960h...")
# !huggingface-cli download facebook/wav2vec2-base-960h \
    --local-dir {WAV2VEC_DIR} 2>&1 | grep -E "Fetching|Downloading|100%|%\|"

# Quick verify
for name, path in [("FlashHead", CKPT_DIR), ("wav2vec2", WAV2VEC_DIR)]:
    if os.path.exists(path) and len(os.listdir(path)) > 0:
        print(f"✅ {name} downloaded")
    else:
        print(f"❌ {name} MISSING — check above for errors")
# Out:
# 📥 Downloading SoulX-FlashHead-1_3B...
# Fetching 18 files:   0%|          | 0/18 [00:00<?, ?it/s]Downloading 'VAE_LTX/diffusion_pytorch_model.safetensors' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/VAE_LTX/4SfAgk9U607e8pVunEB9nSiU10k=.265ca87cb5dff5e37f924286e957324e282fe7710a952a7dafc0df43883e2010.incomplete'
# Downloading '.gitattributes' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.15a20774060b6b9d5696483bd4975ee03d04721c.incomplete'
# Downloading 'Model_Pro/diffusion_pytorch_model.safetensors' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/Model_Pro/4SfAgk9U607e8pVunEB9nSiU10k=.e47e61b9023ea1aac60c0c0fff077289bc6cca443c71907e5a76a411480af250.incomplete'
# Downloading 'README.md' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/Xn7B-BWUGOee2Y6hCZtEhtFu4BE=.7870f5054aee546dd4914677d276c4999b5fbdb1.incomplete'
# Downloading 'VAE_LTX/config.json' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/VAE_LTX/8_PA_wEVGiVa2goH2H4KQOQpvVY=.3a9d81963b21d0c4cfba102fff93676852b52588.incomplete'
# Downloading 'Model_Pro/config.json' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/Model_Pro/8_PA_wEVGiVa2goH2H4KQOQpvVY=.24379b09c3399c1fbb4932548c04003f8f560442.incomplete'
# Downloading 'Model_Lite/diffusion_pytorch_model.safetensors' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/Model_Lite/4SfAgk9U607e8pVunEB9nSiU10k=.aaf1cde6e80ca23f740aae236c47954249f65b151db133cc0f77d3a138ccdf6e.incomplete'
# Fetching 18 files:   6%|▌         | 1/18 [00:00<00:03,  5.60it/s]Downloading 'Model_Lite/config.json' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/Model_Lite/8_PA_wEVGiVa2goH2H4KQOQpvVY=.8d54568d78e315a926d48136c8a6f6aa5286b005.incomplete'
# Downloading 'VAE_Wan/Wan2.1_VAE.pth' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/VAE_Wan/OZTShqo6Di7rh0SEswnfwSjKa9w=.38071ab59bd94681c686fa51d75a1968f64e470262043be31f7a094e442fd981.incomplete'
# Downloading 'assets/flashhead_logo.png' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/assets/dgFPzBcE81LmbEBskY2eB8ykaYQ=.75baa07ed2e3bc190cecbd2a0484ca70e324ee394c06a1bbf2a5a45db214d663.incomplete'
# Downloading 'assets/qitiandasheng.mp4' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/assets/CYTXTvLYlCDGeXSQLZsqYHGBNiA=.72a340f8b74936961c4525592e8f07280f1cc771efa3e0dbc84b731ece6e3198.incomplete'
# Downloading 'assets/einstein.mp4' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/assets/XU1q5pEZy0m1fNhWm_2tpR2_NcY=.c10118b169916df66ff4ac4258ae3b8e959f51b2ba52f6551e1442125655f899.incomplete'
# Downloading 'assets/chengdu.mp4' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/assets/u_cEAApgglP4muKekggz70OFJXU=.95bab76c675fa176b1c2b1be54fe4ac5cb2ad4fb7868196be8a380b608e7b49d.incomplete'
# Downloading 'assets/soul_event_link.png' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/assets/fkgspUo2rfb1_wl46aJGxfTVZVQ=.0debde1e77131dc06aeb0d7d5df4d2c4e043d108df7438d4676668ffc7ca60b3.incomplete'
# Downloading 'assets/soul_group.png' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/assets/3SiTgwOxULZyR4IYATfrBWN5hfI=.9ce0619712325f6533103fda8290352e305fc46a.incomplete'
# Downloading 'assets/wechat_group.png' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/assets/FD2ldUlIly6RkIuQXZiO4ucKuOk=.767697b6f33fcc508d775957fbec4e3fccc0d32170df7758c7cf9d8c1c344dd4.incomplete'
# Downloading 'config.json' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/8_PA_wEVGiVa2goH2H4KQOQpvVY=.75ecfcb904b614fd12edeaa66bcddbcbc425b043.incomplete'
# Downloading 'model_index.json' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/GdzJ-MSUxwmuXEKVy-ZpuQNVts8=.32dfa9a8714bacb4779761b00b41f3441a23cbb1.incomplete'
# Fetching 18 files: 100%|██████████| 18/18 [01:54<00:00,  6.37s/it]
#
# 📥 Downloading wav2vec2-base-960h...
# Fetching 11 files:   0%|          | 0/11 [00:00<?, ?it/s]Downloading 'pytorch_model.bin' to '/content/models/wav2vec2-base-960h/.cache/huggingface/download/Q1p2l2BzM1m6P5jKvr8WTq1TUio=.c34f9827b034a1b9141dbf6f652f8a60eda61cdf5771c9e05bfa99033c92cd96.incomplete'
# Downloading 'config.json' to '/content/models/wav2vec2-base-960h/.cache/huggingface/download/8_PA_wEVGiVa2goH2H4KQOQpvVY=.8ca9cc7496e145e37d09cec17d0c3bf9b8523c8e.incomplete'
# Downloading 'model.safetensors' to '/content/models/wav2vec2-base-960h/.cache/huggingface/download/xGOKKLRSlIhH692hSVvI1-gpoa8=.8aa76ab2243c81747a1f832954586bc566090c83a0ac167df6f31f0fa917d74a.incomplete'
# Downloading 'README.md' to '/content/models/wav2vec2-base-960h/.cache/huggingface/download/Xn7B-BWUGOee2Y6hCZtEhtFu4BE=.c7fe2047d7ac9b9816848c657b2a492ee95b264b.incomplete'
# Downloading '.gitattributes' to '/content/models/wav2vec2-base-960h/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.cf6d51fc9b1a671c35e92d6bd009880937aaa12d.incomplete'
# Downloading 'preprocessor_config.json' to '/content/models/wav2vec2-base-960h/.cache/huggingface/download/PYH5dHjks7Ei0Yd3X0Z8xIwsCNQ=.3f24dc078fcba55ee1d417a413847ead40c093a3.incomplete'
# Downloading 'feature_extractor_config.json' to '/content/models/wav2vec2-base-960h/.cache/huggingface/download/4VpR2OeiJgUtBk492d08IL99QYQ=.52fdd74dc06f40033506e402269fbde5e7adc21d.incomplete'
# Downloading 'special_tokens_map.json' to '/content/models/wav2vec2-base-960h/.cache/huggingface/download/ahkChHUJFxEmOdq5GDFEmerRzCY=.25bc39604f72700b3b8e10bd69bb2f227157edd1.incomplete'
# Fetching 11 files:   9%|▉         | 1/11 [00:00<00:01,  6.31it/s]Download complete. Moving file to /content/models/wav2vec2-base-960h/preprocessor_config.json
# Downloading 'tf_model.h5' to '/content/models/wav2vec2-base-960h/.cache/huggingface/download/a7eHxRFT3OeMBIFg52k2nfj5m7w=.412742825972a6e2e877255ccd8b3416e618df15a7f1e5e4f736aa3632ce33b5.incomplete'
# Downloading 'tokenizer_config.json' to '/content/models/wav2vec2-base-960h/.cache/huggingface/download/vzaExXFZNBay89bvlQv-ZcI6BTg=.978a15a96dbb2d23e2afbc70137cae6c5ce38c8d.incomplete'
# Downloading 'vocab.json' to '/content/models/wav2vec2-base-960h/.cache/huggingface/download/j3m-Hy6QvBddw8RXA1uSWl1AJ0c=.88181b954aa14df68be9b444b3c36585f3078c0a.incomplete'
# Fetching 11 files:  45%|████▌     | 5/11 [00:08<00:11,  1.88s/it]Download complete. Moving file to /content/models/wav2vec2-base-960h/tf_model.h5
# Fetching 11 files: 100%|██████████| 11/11 [00:09<00:00,  1.19it/s]
# ✅ FlashHead downloaded
# ✅ wav2vec2 downloaded

# %%
# @title Step 5: 🔧 Patch All Files (Paths + Share + 16:9 Output)
import os, re
os.chdir("/content/SoulX-FlashHead")

# Reset ALL files to clean state
# !git checkout -- gradio_app.py 2>/dev/null
# !git checkout -- flash_head/utils/facecrop.py 2>/dev/null
# !git checkout -- flash_head/utils/cpu_face_handler.py 2>/dev/null

# ═══════════════════════════════════════════════════
# PART 0: Replace CPUFaceHandler with OpenCV (mediapipe is broken)
# ═══════════════════════════════════════════════════
handler_path = "/content/SoulX-FlashHead/flash_head/utils/cpu_face_handler.py"
handler_code = '''import cv2
import numpy as np
from typing import Tuple, List

class CPUFaceHandler:
    """OpenCV-based face detection (replaces broken mediapipe)."""

    def __init__(self, model_selection: int = 1, min_detection_confidence: float = 0.0):
        # Try DNN first (more accurate), fall back to Haar
        proto = "/content/SoulX-FlashHead/deploy.prototxt"
        caffe = "/content/SoulX-FlashHead/res10_300x300_ssd_iter_140000.caffemodel"
        self.use_dnn = False
        self.use_haar = False

        # Download DNN model if not present
        import urllib.request
        if not os.path.exists(proto):
            try:
                urllib.request.urlretrieve(
                    "https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/face_detector/deploy.prototxt",
                    proto)
            except: pass
        if not os.path.exists(caffe):
            try:
                urllib.request.urlretrieve(
                    "https://github.com/opencv/opencv_3rdparty/raw/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel",
                    caffe)
            except: pass

        if os.path.exists(proto) and os.path.exists(caffe):
            self.net = cv2.dnn.readNetFromCaffe(proto, caffe)
            self.use_dnn = True
        else:
            cascade_path = cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
            self.cascade = cv2.CascadeClassifier(cascade_path)
            self.use_haar = True

    def detect(self, image: np.ndarray) -> Tuple[List, List]:
        bboxs, scores = [], []
        img_h, img_w = image.shape[:2]

        if self.use_dnn:
            blob = cv2.dnn.blobFromImage(image, 1.0, (300, 300), (104.0, 177.0, 123.0))
            self.net.setInput(blob)
            detections = self.net.forward()
            for i in range(detections.shape[2]):
                confidence = float(detections[0, 0, i, 2])
                if confidence > 0.5:
                    # Return RELATIVE coordinates (same as original mediapipe handler)
                    x1 = detections[0, 0, i, 3]
                    y1 = detections[0, 0, i, 4]
                    x2 = detections[0, 0, i, 5]
                    y2 = detections[0, 0, i, 6]
                    bboxs.append([float(x1), float(y1), float(x2), float(y2)])
                    scores.append(confidence)
        elif self.use_haar:
            gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
            faces = self.cascade.detectMultiScale(gray, 1.1, 5, minSize=(30, 30))
            for (x, y, w, h) in faces:
                # Convert to RELATIVE coordinates
                bboxs.append([x/img_w, y/img_h, (x+w)/img_w, (y+h)/img_h])
                scores.append(1.0)

        return bboxs, scores

    def __call__(self, image: np.ndarray) -> Tuple[List, List]:
        return self.detect(image)
'''

import os as _os
with open(handler_path, "w") as f:
    f.write("import os\n" + handler_code)
print("✅ Replaced CPUFaceHandler with OpenCV (no mediapipe)")

# ═══════════════════════════════════════════════════
# PART 1: Patch facecrop.py to SAVE the crop bbox
# ═══════════════════════════════════════════════════
facecrop_path = "/content/SoulX-FlashHead/flash_head/utils/facecrop.py"
with open(facecrop_path, "r") as f:
    fc_code = f.read()

fc_code = fc_code.replace(
    'import os',
    'import os\nimport json\n\n_LAST_CROP_BBOX = None'
)

fc_code = fc_code.replace(
    '    crop_face = face_image.crop(scaled_bbox)',
    '    global _LAST_CROP_BBOX\n'
    '    _LAST_CROP_BBOX = scaled_bbox + [img_w, img_h]\n'
    '    try:\n'
    '        with open("/tmp/_flashhead_crop_bbox.json", "w") as _bf:\n'
    '            json.dump({"bbox": scaled_bbox, "img_w": img_w, "img_h": img_h}, _bf)\n'
    '    except: pass\n'
    '    crop_face = face_image.crop(scaled_bbox)'
)

with open(facecrop_path, "w") as f:
    f.write(fc_code)
print("✅ Patched facecrop.py to save crop bbox")

# ═══════════════════════════════════════════════════
# PART 2: Patch gradio_app.py
# ═══════════════════════════════════════════════════
filepath = "/content/SoulX-FlashHead/gradio_app.py"
with open(filepath, "r") as f:
    code = f.read()

# Fix model paths
code = code.replace('value="models/SoulX-FlashHead-1_3B"', 'value="/content/models/SoulX-FlashHead-1_3B"')
code = code.replace('value="models/wav2vec2-base-960h"', 'value="/content/models/wav2vec2-base-960h"')

# Default to lite
code = code.replace('value="pro",', 'value="lite",')

# Default face crop ON
code = code.replace(
    'label="Use Face Crop",\n                value=False,',
    'label="Use Face Crop",\n                value=True,'
)

# Share mode
if 'app.launch(share=True' not in code:
    code = code.replace('app.launch()', 'app.launch(share=True, debug=True)')

# Branding
match = re.search(r'^( *)gr\.Markdown\("# ⚡ SoulX-FlashHead Video Generator"\)', code, re.MULTILINE)
if match:
    old_line = match.group(0)
    ind = match.group(1)
    brand_html = (
        '<div style="text-align:center; padding:25px; '
        'background:linear-gradient(135deg,#667eea 0%,#764ba2 100%); '
        'border-radius:12px; box-shadow:0 8px 16px rgba(0,0,0,0.2); margin-bottom:20px;">'
        '<h1 style="font-size:2.2em; margin:0; color:white;">🎬 SoulX FlashHead Lite - AI Talking Head</h1>'
        '<p style="font-size:1.1em; color:rgba(255,255,255,0.9); margin:6px 0 12px;">'
        'Audio-Driven Portrait Animation | Lite &amp; Pro Models</p>'
        '<div style="display:flex; justify-content:center; gap:12px; flex-wrap:wrap;">'
        '<a href="https://www.youtube.com/@AiQuestacademy" target="_blank" '
        'style="background:#FF0000; color:#fff; padding:8px 18px; border-radius:8px; '
        'text-decoration:none; font-weight:600; font-size:0.95em;">'
        '▶ YouTube - AIQUEST</a>'
        '<a href="https://x.com/AiQuestacademy" target="_blank" '
        'style="background:#000; color:#fff; padding:8px 18px; border-radius:8px; '
        'text-decoration:none; font-weight:600; font-size:0.95em;">'
        '𝕏 Follow on X</a></div>'
        '<p style="margin-top:10px; font-size:0.85em; color:rgba(255,255,255,0.7);">'
        'Notebook by <b>AIQUEST</b> — Subscribe for more AI tools &amp; tutorials!</p></div>'
    )
    new_line = ind + 'gr.HTML(' + repr(brand_html) + ')'
    code = code.replace(old_line, new_line)
    print("✅ Branding injected")

# ── Inject post-processing into run_inference ──
run_inf_pattern = re.search(
    r'(logger\.info\(f"Saved to \{final_video_path\}"\))\s*\n(\s*)(return final_video_path)',
    code
)
if run_inf_pattern:
    old_block = run_inf_pattern.group(0)
    ind = run_inf_pattern.group(2)
    new_block = (
        run_inf_pattern.group(1) + '\n'
        + ind + '# ── 16:9 Aspect Ratio Post-Processing ──\n'
        + ind + 'try:\n'
        + ind + '    final_video_path = _composite_to_original(final_video_path, cond_image)\n'
        + ind + 'except Exception as e:\n'
        + ind + '    import traceback; logger.error(f"COMPOSITE FAILED: {e}\\n{traceback.format_exc()}")\n'
        + ind + 'return final_video_path'
    )
    code = code.replace(old_block, new_block)
    print("✅ Post-processing injected into run_inference")

# ── Inject into run_multi_gpu_inference ──
multi_pattern = re.search(
    r'(if os\.path\.exists\(save_path\):)\s*\n(\s*)(return save_path)',
    code
)
if multi_pattern:
    old_block2 = multi_pattern.group(0)
    ind2 = multi_pattern.group(2)
    new_block2 = (
        multi_pattern.group(1) + '\n'
        + ind2 + '# ── 16:9 Aspect Ratio Post-Processing ──\n'
        + ind2 + 'try:\n'
        + ind2 + '    save_path = _composite_to_original(save_path, cond_image)\n'
        + ind2 + 'except Exception as e:\n'
        + ind2 + '    import traceback; logger.error(f"COMPOSITE FAILED: {e}\\n{traceback.format_exc()}")\n'
        + ind2 + 'return save_path'
    )
    code = code.replace(old_block2, new_block2)
    print("✅ Post-processing injected into run_multi_gpu_inference")

# ── Add composite function ──
first_def = code.index("\ndef ")
composite_func = '''
def _composite_to_original(video_path, original_image_path):
    """
    Reads the EXACT crop bbox saved by facecrop.py during model inference,
    then pastes each 512x512 generated frame back into that exact region.
    """
    import cv2, json, numpy as np, subprocess

    bbox_file = "/tmp/_flashhead_crop_bbox.json"
    if not os.path.exists(bbox_file):
        logger.info("No crop bbox file found — face_crop was likely disabled, skipping composite")
        return video_path

    with open(bbox_file, "r") as f:
        crop_data = json.load(f)

    crop_x1, crop_y1, crop_x2, crop_y2 = crop_data["bbox"]
    orig_img_w = crop_data["img_w"]
    orig_img_h = crop_data["img_h"]

    os.remove(bbox_file)

    aspect = max(orig_img_w, orig_img_h) / max(min(orig_img_w, orig_img_h), 1)
    if aspect < 1.15:
        logger.info(f"Original {orig_img_w}x{orig_img_h} is ~square, skipping composite")
        return video_path

    crop_w = crop_x2 - crop_x1
    crop_h = crop_y2 - crop_y1

    logger.info(f"COMPOSITE: using EXACT model bbox ({crop_x1},{crop_y1})-({crop_x2},{crop_y2}) = {crop_w}x{crop_h} in {orig_img_w}x{orig_img_h}")

    orig = cv2.imread(original_image_path)
    if orig is None:
        logger.warning(f"Could not read original image: {original_image_path}")
        return video_path

    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS) or 25.0
    output_path = video_path.replace(".mp4", "_ar.mp4")

    out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*"mp4v"), fps, (orig_img_w, orig_img_h))

    mask = np.ones((crop_h, crop_w), dtype=np.float32)
    feather = max(min(crop_w, crop_h) // 12, 6)
    for i in range(feather):
        a = i / feather
        mask[i, :] *= a
        mask[-(i+1), :] *= a
        mask[:, i] *= a
        mask[:, -(i+1)] *= a
    mask_3ch = mask[:, :, np.newaxis]

    frame_count = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        resized = cv2.resize(frame, (crop_w, crop_h), interpolation=cv2.INTER_LANCZOS4)
        canvas = orig.copy()
        roi = canvas[crop_y1:crop_y2, crop_x1:crop_x2].astype(np.float32)
        blended = (resized.astype(np.float32) * mask_3ch + roi * (1 - mask_3ch)).astype(np.uint8)
        canvas[crop_y1:crop_y2, crop_x1:crop_x2] = blended
        out.write(canvas)
        frame_count += 1

    cap.release()
    out.release()

    final_path = output_path.replace(".mp4", "_final.mp4")
    subprocess.run(["ffmpeg", "-y", "-i", output_path, "-i", video_path,
                    "-c:v", "libx264", "-c:a", "aac", "-map", "0:v", "-map", "1:a",
                    "-shortest", final_path], capture_output=True)

    if os.path.exists(final_path) and os.path.getsize(final_path) > 0:
        os.replace(final_path, video_path)
        if os.path.exists(output_path):
            os.remove(output_path)
        logger.info(f"✅ Composited {frame_count} frames -> {orig_img_w}x{orig_img_h}, saved to {video_path}")
        return video_path

    if os.path.exists(output_path):
        os.replace(output_path, video_path)
    return video_path

'''
code = code[:first_def] + composite_func + code[first_def:]

with open(filepath, "w") as f:
    f.write(code)

# ═══════════════════════════════════════════════════
# Verify everything
# ═══════════════════════════════════════════════════
with open(filepath, "r") as f:
    final = f.read()
with open(facecrop_path, "r") as f:
    fc_final = f.read()
with open(handler_path, "r") as f:
    handler_final = f.read()

checks = [
    ("_composite_to_original(final_video_path, cond_image)" in final, "Post-process in run_inference"),
    ("_composite_to_original(save_path, cond_image)" in final, "Post-process in run_multi_gpu"),
    ("def _composite_to_original" in final, "Composite function"),
    ("_flashhead_crop_bbox.json" in final, "Reads exact bbox from model"),
    ("_flashhead_crop_bbox.json" in fc_final, "facecrop.py saves bbox"),
    ("mediapipe" not in handler_final, "CPUFaceHandler uses OpenCV (no mediapipe)"),
    ("cv2.dnn" in handler_final, "DNN face detector in handler"),
    ("value=True," in final and "Use Face Crop" in final, "Face crop defaults ON"),
    ("/content/models/" in final, "Model paths"),
    ("share=True" in final, "Share mode"),
]
print("\n── Verification ──")
for ok, label in checks:
    print(f"{'✅' if ok else '❌'} {label}")

# Test that the handler actually works
print("\n── Handler Test ──")
try:
    import sys
    for mod in list(sys.modules.keys()):
        if "face_handler" in mod or "facecrop" in mod:
            del sys.modules[mod]
    from flash_head.utils.cpu_face_handler import CPUFaceHandler
    handler = CPUFaceHandler()
    print(f"✅ CPUFaceHandler initialized (dnn={handler.use_dnn}, haar={handler.use_haar})")
except Exception as e:
    print(f"❌ CPUFaceHandler FAILED: {e}")
# Out:
# ✅ Replaced CPUFaceHandler with OpenCV (no mediapipe)
# ✅ Patched facecrop.py to save crop bbox
# ✅ Branding injected
# ✅ Post-processing injected into run_inference
# ✅ Post-processing injected into run_multi_gpu_inference
#
# ── Verification ──
# ✅ Post-process in run_inference
# ✅ Post-process in run_multi_gpu
# ✅ Composite function
# ✅ Reads exact bbox from model
# ✅ facecrop.py saves bbox
# ❌ CPUFaceHandler uses OpenCV (no mediapipe)
# ✅ DNN face detector in handler
# ❌ Face crop defaults ON
# ✅ Model paths
# ✅ Share mode
#
# ── Handler Test ──
# ✅ CPUFaceHandler initialized (dnn=True, haar=False)

# %%
# @title Quick Fix: Force face_crop default ON
filepath = "/content/SoulX-FlashHead/gradio_app.py"
with open(filepath, "r") as f:
    code = f.read()

import re
# Match the checkbox regardless of whitespace
code = re.sub(
    r'(use_face_crop_input\s*=\s*gr\.Checkbox\([^)]*?)value\s*=\s*False',
    r'\1value=True',
    code
)

with open(filepath, "w") as f:
    f.write(code)

# Verify
with open(filepath, "r") as f:
    final = f.read()

match = re.search(r'use_face_crop_input.*?value\s*=\s*(True|False)', final, re.DOTALL)
print(f"✅ Face crop default: {match.group(1)}" if match else "❌ Not found")
# Out:
# ✅ Face crop default: True

# %%
# @title Step 6: 🚀 Launch SoulX FlashHead Gradio UI
# %cd /content/SoulX-FlashHead

print("🚀 Launching SoulX FlashHead Lite...")
print("🔗 Watch for the public Gradio URL below!\n")

# !python gradio_app.py
# Out:
# /content/SoulX-FlashHead
# 🚀 Launching SoulX FlashHead Lite...
# 🔗 Watch for the public Gradio URL below!
#
# 2026-04-07 15:10:32.984593: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775574633.006362    4884 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775574633.013432    4884 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775574633.032749    4884 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775574633.032776    4884 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775574633.032780    4884 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775574633.032783    4884 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# /content/SoulX-FlashHead/gradio_app.py:386: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(title="SoulX-FlashHead Video Generator", theme=gr.themes.Soft()) as app:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://a91bfbd442291603c9.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# 2026-04-07 15:30:34.993 | INFO     | __main__:run_inference:253 - Loading pipeline with ckpt_dir=/content/models/SoulX-FlashHead-1_3B, wav2vec_dir=/content/models/wav2vec2-base-960h
# 2026-04-07 15:30:34.993 | INFO     | flash_head.inference:get_pipeline:17 - ulysses_degree: 1, ring_degree: 1, device: cuda
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at /content/models/wav2vec2-base-960h and are newly initialized: ['masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# W0407 15:31:25.653000 4884 torch/_inductor/utils.py:1679] [0/0] Not enough SMs to use max_autotune_gemm mode
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/variables/functions.py:2056: UserWarning: Dynamo detected a call to a `functools.lru_cache`-wrapped function. Dynamo ignores the cache wrapper and directly traces the wrapped function. Silent incorrectness is only a *potential* risk, not something we have observed. Enable TORCH_LOGS="+dynamo" for a DEBUG stack trace.
#   torch._dynamo.utils.warn_once(msg)
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# 2026-04-07 15:31:59.564 | INFO     | __main__:run_inference:297 - Data preparation done. Start to generate video...
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/lowering.py:2156: UserWarning: Torchinductor does not support code generation for complex operators. Performance may be worse than eager.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /content/SoulX-FlashHead/flash_head/src/modules/flash_head_model.py:544: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(dtype=torch.float32):
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# [generate] model denoise per step: 76.40134835243225s
# /content/SoulX-FlashHead/flash_head/src/modules/flash_head_model.py:544: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(dtype=torch.float32):
# [generate] model denoise per step: 1.694251298904419s
# [generate] model denoise per step: 1.7077057361602783s
# [generate] model denoise per step: 1.7298557758331299s
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# [generate] decode video frames: 24.992425680160522s
# [generate] color correction: 0.059734344482421875s
# [generate] encode motion frames: 1.538442611694336s
# 2026-04-07 15:33:48.331 | INFO     | __main__:run_inference:363 - Generate video chunk-0 done, cost time: 108.13s
# /content/SoulX-FlashHead/flash_head/src/modules/flash_head_model.py:544: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(dtype=torch.float32):
# [generate] model denoise per step: 1.8202457427978516s
# [generate] model denoise per step: 1.8345088958740234s
# [generate] model denoise per step: 1.8372137546539307s
# [generate] model denoise per step: 1.8376250267028809s
# [generate] decode video frames: 6.07572603225708s
# [generate] color correction: 0.0473484992980957s
# [generate] encode motion frames: 1.6343791484832764s
# 2026-04-07 15:34:03.505 | INFO     | __main__:run_inference:363 - Generate video chunk-1 done, cost time: 15.09s
# [generate] model denoise per step: 1.832740306854248s
# [generate] model denoise per step: 1.8335623741149902s
# [generate] model denoise per step: 1.8160171508789062s
# [generate] model denoise per step: 1.7915213108062744s
# [generate] decode video frames: 5.58424186706543s
# [generate] color correction: 0.0453038215637207s
# [generate] encode motion frames: 1.4759345054626465s
# 2026-04-07 15:34:17.972 | INFO     | __main__:run_inference:363 - Generate video chunk-2 done, cost time: 14.39s
# [generate] model denoise per step: 1.699472188949585s
# [generate] model denoise per step: 1.7017474174499512s
# [generate] model denoise per step: 1.6864221096038818s
# [generate] model denoise per step: 1.6752164363861084s
# [generate] decode video frames: 5.246882677078247s
# [generate] color correction: 0.0444340705871582s
# [generate] encode motion frames: 1.4010426998138428s
# 2026-04-07 15:34:31.517 | INFO     | __main__:run_inference:363 - Generate video chunk-3 done, cost time: 13.46s
# [generate] model denoise per step: 1.6385364532470703s
# [generate] model denoise per step: 1.6336729526519775s
# [generate] model denoise per step: 1.633791208267212s
# [generate] model denoise per step: 1.6344895362854004s
# [generate] decode video frames: 5.152421236038208s
# [generate] color correction: 0.04427957534790039s
# [generate] encode motion frames: 1.3892905712127686s
# 2026-04-07 15:34:44.731 | INFO     | __main__:run_inference:363 - Generate video chunk-4 done, cost time: 13.13s
# [generate] model denoise per step: 1.6289088726043701s
# [generate] model denoise per step: 1.631563663482666s
# [generate] model denoise per step: 1.6378028392791748s
# [generate] model denoise per step: 1.6415445804595947s
# [generate] decode video frames: 5.220332145690918s
# [generate] color correction: 0.04377388954162598s
# [generate] encode motion frames: 1.4201154708862305s
# 2026-04-07 15:34:58.050 | INFO     | __main__:run_inference:363 - Generate video chunk-5 done, cost time: 13.23s
# [generate] model denoise per step: 1.6597716808319092s
# [generate] model denoise per step: 1.669203281402588s
# [generate] model denoise per step: 1.6794304847717285s
# [generate] model denoise per step: 1.688328742980957s
# [generate] decode video frames: 5.402726888656616s
# [generate] color correction: 0.045203447341918945s
# [generate] encode motion frames: 1.4742584228515625s
# 2026-04-07 15:35:11.758 | INFO     | __main__:run_inference:363 - Generate video chunk-6 done, cost time: 13.63s
# [generate] model denoise per step: 1.7086102962493896s
# [generate] model denoise per step: 1.729245662689209s
# [generate] model denoise per step: 1.7277193069458008s
# [generate] model denoise per step: 1.7400803565979004s
# [generate] decode video frames: 5.568040609359741s
# [generate] color correction: 0.04514646530151367s
# [generate] encode motion frames: 1.5076963901519775s
# 2026-04-07 15:35:25.874 | INFO     | __main__:run_inference:363 - Generate video chunk-7 done, cost time: 14.03s
# [generate] model denoise per step: 1.7469346523284912s
# [generate] model denoise per step: 1.7512478828430176s
# [generate] model denoise per step: 1.7450370788574219s
# [generate] model denoise per step: 1.7442164421081543s
# [generate] decode video frames: 5.5658135414123535s
# [generate] color correction: 0.04545736312866211s
# [generate] encode motion frames: 1.4994351863861084s
# 2026-04-07 15:35:40.085 | INFO     | __main__:run_inference:363 - Generate video chunk-8 done, cost time: 14.10s
# [generate] model denoise per step: 1.7303047180175781s
# [generate] model denoise per step: 1.725022792816162s
# [generate] model denoise per step: 1.7208914756774902s
# [generate] model denoise per step: 1.7216436862945557s
# [generate] decode video frames: 5.4382336139678955s
# [generate] color correction: 0.04550909996032715s
# [generate] encode motion frames: 1.4578649997711182s
# 2026-04-07 15:35:54.033 | INFO     | __main__:run_inference:363 - Generate video chunk-9 done, cost time: 13.85s
# [generate] model denoise per step: 1.6862075328826904s
# [generate] model denoise per step: 1.6920130252838135s
# [generate] model denoise per step: 1.6836001873016357s
# [generate] model denoise per step: 1.6851367950439453s
# [generate] decode video frames: 5.344983100891113s
# [generate] color correction: 0.04394865036010742s
# [generate] encode motion frames: 1.434366226196289s
# 2026-04-07 15:36:07.694 | INFO     | __main__:run_inference:363 - Generate video chunk-10 done, cost time: 13.58s
# [generate] model denoise per step: 1.668025255203247s
# [generate] model denoise per step: 1.6748051643371582s
# [generate] model denoise per step: 1.668745994567871s
# [generate] model denoise per step: 1.6760554313659668s
# [generate] decode video frames: 5.334253787994385s
# [generate] color correction: 0.04400467872619629s
# [generate] encode motion frames: 1.4383299350738525s
# 2026-04-07 15:36:21.291 | INFO     | __main__:run_inference:363 - Generate video chunk-11 done, cost time: 13.51s
# [generate] model denoise per step: 1.6780781745910645s
# [generate] model denoise per step: 1.681962490081787s
# [generate] model denoise per step: 1.6904664039611816s
# [generate] model denoise per step: 1.6865603923797607s
# [generate] decode video frames: 5.396689176559448s
# [generate] color correction: 0.04431009292602539s
# [generate] encode motion frames: 1.4575040340423584s
# 2026-04-07 15:36:35.025 | INFO     | __main__:run_inference:363 - Generate video chunk-12 done, cost time: 13.64s
# [generate] model denoise per step: 1.69087553024292s
# [generate] model denoise per step: 1.6918797492980957s
# [generate] model denoise per step: 1.6999602317810059s
# [generate] model denoise per step: 1.705334186553955s
# [generate] decode video frames: 5.452485084533691s
# [generate] color correction: 0.044628143310546875s
# [generate] encode motion frames: 1.4727153778076172s
# 2026-04-07 15:36:48.874 | INFO     | __main__:run_inference:363 - Generate video chunk-13 done, cost time: 13.76s
# [generate] model denoise per step: 1.6989827156066895s
# [generate] model denoise per step: 1.7145476341247559s
# [generate] model denoise per step: 1.7093584537506104s
# [generate] model denoise per step: 1.7157928943634033s
# [generate] decode video frames: 5.477560758590698s
# [generate] color correction: 0.044818878173828125s
# [generate] encode motion frames: 1.4740774631500244s
# 2026-04-07 15:37:02.799 | INFO     | __main__:run_inference:363 - Generate video chunk-14 done, cost time: 13.84s
# [generate] model denoise per step: 1.7059719562530518s
# [generate] model denoise per step: 1.7086198329925537s
# [generate] model denoise per step: 1.7108263969421387s
# [generate] model denoise per step: 1.7170672416687012s
# [generate] decode video frames: 5.454874753952026s
# [generate] color correction: 0.04439568519592285s
# [generate] encode motion frames: 1.4690227508544922s
# 2026-04-07 15:37:16.700 | INFO     | __main__:run_inference:363 - Generate video chunk-15 done, cost time: 13.82s
# [generate] model denoise per step: 1.6996171474456787s
# [generate] model denoise per step: 1.7098474502563477s
# [generate] model denoise per step: 1.7090723514556885s
# [generate] model denoise per step: 1.7075557708740234s
# [generate] decode video frames: 5.448498725891113s
# [generate] color correction: 0.04465675354003906s
# [generate] encode motion frames: 1.461225986480713s
# 2026-04-07 15:37:30.574 | INFO     | __main__:run_inference:363 - Generate video chunk-16 done, cost time: 13.79s
# [generate] model denoise per step: 1.6995306015014648s
# [generate] model denoise per step: 1.7114768028259277s
# [generate] model denoise per step: 1.7139770984649658s
# [generate] model denoise per step: 1.7030022144317627s
# [generate] decode video frames: 5.448788642883301s
# [generate] color correction: 0.044850826263427734s
# [generate] encode motion frames: 1.4655773639678955s
# 2026-04-07 15:37:44.451 | INFO     | __main__:run_inference:363 - Generate video chunk-17 done, cost time: 13.79s
# [generate] model denoise per step: 1.7047672271728516s
# [generate] model denoise per step: 1.7144291400909424s
# [generate] model denoise per step: 1.7106530666351318s
# [generate] model denoise per step: 1.7025582790374756s
# [generate] decode video frames: 5.437629461288452s
# [generate] color correction: 0.04547882080078125s
# [generate] encode motion frames: 1.469165563583374s
# 2026-04-07 15:37:58.356 | INFO     | __main__:run_inference:363 - Generate video chunk-18 done, cost time: 13.79s
# [generate] model denoise per step: 1.706392526626587s
# [generate] model denoise per step: 1.7012932300567627s
# [generate] model denoise per step: 1.7008278369903564s
# [generate] model denoise per step: 1.6988096237182617s
# [generate] decode video frames: 5.421578884124756s
# [generate] color correction: 0.04566812515258789s
# [generate] encode motion frames: 1.466475009918213s
# 2026-04-07 15:38:12.212 | INFO     | __main__:run_inference:363 - Generate video chunk-19 done, cost time: 13.75s
# [generate] model denoise per step: 1.699187994003296s
# [generate] model denoise per step: 1.7121076583862305s
# [generate] model denoise per step: 1.7001981735229492s
# [generate] model denoise per step: 1.7015697956085205s
# [generate] decode video frames: 5.424316883087158s
# [generate] color correction: 0.04439377784729004s
# [generate] encode motion frames: 1.462674617767334s
# 2026-04-07 15:38:26.046 | INFO     | __main__:run_inference:363 - Generate video chunk-20 done, cost time: 13.75s
# [generate] model denoise per step: 1.6978089809417725s
# [generate] model denoise per step: 1.7045884132385254s
# [generate] model denoise per step: 1.695690393447876s
# [generate] model denoise per step: 1.6981971263885498s
# [generate] decode video frames: 5.410850524902344s
# [generate] color correction: 0.04458141326904297s
# [generate] encode motion frames: 1.4604108333587646s
# 2026-04-07 15:38:39.847 | INFO     | __main__:run_inference:363 - Generate video chunk-21 done, cost time: 13.72s
# [generate] model denoise per step: 1.6953670978546143s
# [generate] model denoise per step: 1.6986305713653564s
# [generate] model denoise per step: 1.6993992328643799s
# [generate] model denoise per step: 1.697533130645752s
# [generate] decode video frames: 5.391319036483765s
# [generate] color correction: 0.04459953308105469s
# [generate] encode motion frames: 1.4610586166381836s
# 2026-04-07 15:38:53.625 | INFO     | __main__:run_inference:363 - Generate video chunk-22 done, cost time: 13.69s
# [generate] model denoise per step: 1.6942484378814697s
# [generate] model denoise per step: 1.6965060234069824s
# [generate] model denoise per step: 1.6904089450836182s
# [generate] model denoise per step: 1.699939250946045s
# [generate] decode video frames: 5.400248289108276s
# [generate] color correction: 0.04464316368103027s
# [generate] encode motion frames: 1.4575791358947754s
# 2026-04-07 15:39:07.398 | INFO     | __main__:run_inference:363 - Generate video chunk-23 done, cost time: 13.69s
# [generate] model denoise per step: 1.689823865890503s
# [generate] model denoise per step: 1.694258213043213s
# [generate] model denoise per step: 1.6931438446044922s
# [generate] model denoise per step: 1.6972217559814453s
# [generate] decode video frames: 5.406548976898193s
# [generate] color correction: 0.04400944709777832s
# [generate] encode motion frames: 1.4559094905853271s
# 2026-04-07 15:39:21.176 | INFO     | __main__:run_inference:363 - Generate video chunk-24 done, cost time: 13.69s
# [generate] model denoise per step: 1.6886589527130127s
# [generate] model denoise per step: 1.6926507949829102s
# [generate] model denoise per step: 1.6923353672027588s
# [generate] model denoise per step: 1.6955113410949707s
# [generate] decode video frames: 5.386390924453735s
# [generate] color correction: 0.044621944427490234s
# [generate] encode motion frames: 1.4581961631774902s
# 2026-04-07 15:39:34.923 | INFO     | __main__:run_inference:363 - Generate video chunk-25 done, cost time: 13.66s
# [generate] model denoise per step: 1.6923511028289795s
# [generate] model denoise per step: 1.6906771659851074s
# [generate] model denoise per step: 1.6914207935333252s
# [generate] model denoise per step: 1.6945948600769043s
# [generate] decode video frames: 5.401748895645142s
# [generate] color correction: 0.04461956024169922s
# [generate] encode motion frames: 1.457526445388794s
# 2026-04-07 15:39:48.686 | INFO     | __main__:run_inference:363 - Generate video chunk-26 done, cost time: 13.68s
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'gradio_results/res_20260407-153948-738_temp.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.1.100
#   Duration: 00:00:25.92, start: 0.000000, bitrate: 691 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 512x512, 690 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc61.3.100 libx264
# Guessed Channel Layout for Input Stream #1.0 : mono
# Input #1, wav, from '/tmp/gradio/6cb7c3c41920e6b77b26446abc7ec072d836929ade24da61420a19f049b9e244/0000-Introduction.wav':
#   Duration: 00:00:25.89, bitrate: 384 kb/s
#   Stream #1:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #1:0 -> #0:1 (pcm_s16le (native) -> aac (native))
# Press [q] to stop, [?] for help
# Output #0, mp4, to 'gradio_results/res_20260407-153948-738.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 512x512, q=2-31, 690 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc61.3.100 libx264
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 24000 Hz, mono, fltp, 69 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 aac
# frame=  648 fps=0.0 q=-1.0 Lsize=    2417kB time=00:00:25.88 bitrate= 765.2kbits/s speed= 169x
# video:2185kB audio:220kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.496839%
# [aac @ 0x5b00ed48f000] Qavg: 139.253
# 2026-04-07 15:40:01.999 | INFO     | __main__:run_inference:377 - Saved to gradio_results/res_20260407-153948-738.mp4
# 2026-04-07 15:40:02.000 | INFO     | __main__:_composite_to_original:51 - COMPOSITE: using EXACT model bbox (412,0)-(1005,590) = 593x590 in 1376x768
# 2026-04-07 15:40:38.284 | INFO     | __main__:_composite_to_original:99 - ✅ Composited 648 frames -> 1376x768, saved to gradio_results/res_20260407-153948-738.mp4
# 2026-04-07 15:44:04.291 | INFO     | __main__:run_inference:253 - Loading pipeline with ckpt_dir=/content/models/SoulX-FlashHead-1_3B, wav2vec_dir=/content/models/wav2vec2-base-960h
# 2026-04-07 15:44:04.292 | INFO     | flash_head.inference:get_pipeline:17 - ulysses_degree: 1, ring_degree: 1, device: cuda
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at /content/models/wav2vec2-base-960h and are newly initialized: ['masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# 2026-04-07 15:46:09.675 | ERROR    | __main__:run_inference:273 - Error in get_base_data: CUDA out of memory. Tried to allocate 5.06 GiB. GPU 0 has a total capacity of 14.56 GiB of which 3.76 GiB is free. Process 3879 has 120.00 MiB memory in use. Including non-PyTorch memory, this process has 10.68 GiB memory in use. Of the allocated memory 5.09 GiB is allocated by PyTorch, and 5.47 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Traceback (most recent call last):
#   File "/content/SoulX-FlashHead/gradio_app.py", line 271, in run_inference
#     get_base_data(pipeline, cond_image_path_or_dir=cond_image, base_seed=base_seed, use_face_crop=use_face_crop)
#   File "/content/SoulX-FlashHead/flash_head/inference.py", line 40, in get_base_data
#     pipeline.prepare_params(
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 124, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/SoulX-FlashHead/flash_head/src/pipeline/flash_head_pipeline.py", line 189, in prepare_params
#     self.ref_img_latent_dict[person_name] = self.vae.encode(video_frames) # (16, 9, 64, 64) / (128, 5, 16, 16)
#                                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py", line 953, in compile_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/content/SoulX-FlashHead/flash_head/wan/modules/vae.py", line 1298, in encode
#     out = self.model.encode(video, self.scale).squeeze(0)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/SoulX-FlashHead/flash_head/wan/modules/vae.py", line 784, in encode
#     out_ = self.encoder(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/SoulX-FlashHead/flash_head/wan/modules/vae.py", line 375, in forward
#     x = layer(x, feat_cache, feat_idx)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/SoulX-FlashHead/flash_head/wan/modules/vae.py", line 243, in forward
#     x = layer(x, feat_cache[idx])
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/SoulX-FlashHead/flash_head/wan/modules/vae.py", line 42, in forward
#     return super().forward(x)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py", line 723, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py", line 718, in _conv_forward
#     return F.conv3d(
#            ^^^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 5.06 GiB. GPU 0 has a total capacity of 14.56 GiB of which 3.76 GiB is free. Process 3879 has 120.00 MiB memory in use. Including non-PyTorch memory, this process has 10.68 GiB memory in use. Of the allocated memory 5.09 GiB is allocated by PyTorch, and 5.47 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/queueing.py", line 759, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/route_utils.py", line 354, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2191, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 1698, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/to_thread.py", line 63, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 2518, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 1002, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/utils.py", line 915, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/content/SoulX-FlashHead/gradio_app.py", line 498, in dispatch_inference
#     return run_inference(ckpt, wav2vec, model_type, img, audio, enc_mode, seed, use_face_crop)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/SoulX-FlashHead/gradio_app.py", line 274, in run_inference
#     raise gr.Error(f"Error processing inputs: {e}")
# gradio.exceptions.Error: 'Error processing inputs: CUDA out of memory. Tried to allocate 5.06 GiB. GPU 0 has a total capacity of 14.56 GiB of which 3.76 GiB is free. Process 3879 has 120.00 MiB memory in use. Including non-PyTorch memory, this process has 10.68 GiB memory in use. Of the allocated memory 5.09 GiB is allocated by PyTorch, and 5.47 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)'

# %% [markdown]
# ---
#
# <div align="center">
#
# ### 🎉 Enjoyed this notebook?
#
# If this was helpful, please **⭐ star the repo** and **subscribe** for more free AI tools & tutorials!
#
#   <a href="https://www.youtube.com/@aiquestacademy?sub_confirmation=1">
#     <img src="https://img.shields.io/badge/▶%20Subscribe%20on%20YouTube-FF0000?style=for-the-badge&logo=youtube&logoColor=white" />
#   </a>
#   &nbsp;
#   <a href="https://x.com/aiquestacademy">
#     <img src="https://img.shields.io/badge/Follow%20on%20𝕏-0000?style=for-the-badge&logo=x&logoColor=white" />
#   </a>
#
# **Made with ❤️ by AIQUEST** | [@aiquestacademy](https://youtube.com/@aiquestacademy)
#
# </div>
